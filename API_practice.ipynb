# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e8c97829fd221b9ed8849cd6e670525

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e8c97829fd221b9ed8849cd6e670525&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.06,"lat":42.36},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":46.78,"feels_like":35.74,"temp_min":46,"temp_max":48,"pressure":1018,"humidity":52},"visibility":10000,"wind":{"speed":12.75,"deg":280,"gust":19.46},"clouds":{"all":75},"dt":1605382297,"sys":{"type":1,"id":3486,"country":"US","sunrise":1605353671,"sunset":1605388993},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 46.78,
#   'feels_like': 35.74,
#   'temp_min': 46,
#   'temp_max': 48,
#   'pressure': 1018,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 12.75, 'deg': 280, 'gust': 19.46},
#  'clouds': {'all': 75},
#  'dt': 1605382297,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1605353671,
#   'sunset': 1605388993},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.json():
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 46.78,
#   'feels_like': 35.74,
#   'temp_min': 46,
#   'temp_max': 48,
#   'pressure': 1018,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 12.75, 'deg': 280, 'gust': 19.46},
#  'clouds': {'all': 75},
#  'dt': 1605382297,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1605353671,
#   'sunset': 1605388993},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 48 52 75 12.75

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 11, 14, 19, 31, 37)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
import numpy as np
from citipy import citipy

# %%
#Used Citipy API to create latittude and lonigitute 
#to get cites and created a list of unique cites usign random formula Uniform get you folating numbers
#Used for to remove dups.

lat_lngs = []
cities = []

lats = np.random.uniform(low = - 90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = - 180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats,lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
#Get a count of cites using len
len(cities)
# Out:
# 606

# %%
## Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 49 | biak
# Processing Record 2 of Set 49 | vaini
# Processing Record 3 of Set 49 | mataura
# Processing Record 4 of Set 49 | malinovskiy
# Processing Record 5 of Set 49 | puerto ayacucho
# Processing Record 6 of Set 49 | rawson
# Processing Record 7 of Set 49 | berbera
# Processing Record 8 of Set 49 | marsa matruh
# Processing Record 9 of Set 49 | qaanaaq
# Processing Record 10 of Set 49 | jurmala
# Processing Record 11 of Set 49 | new norfolk
# Processing Record 12 of Set 49 | najran
# Processing Record 13 of Set 49 | taolanaro
# Processing Record 14 of Set 49 | cape town
# Processing Record 15 of Set 49 | puerto narino
# Processing Record 16 of Set 49 | vanino
# Processing Record 17 of Set 49 | ushuaia
# Processing Record 18 of Set 49 | ahipara
# Processing Record 19 of Set 49 | airai
# Processing Record 20 of Set 49 | kodiak
# Processing Record 21 of Set 49 | mandalgovi
# Processing Record 22 of Set 49 | carnarvon
# Processing Record 23 of Set 49 | bereda
# Processing Record 24 of Set 49 | belushya guba
# Processing Record 25 of Set 49 | rikitea
# Processing Record 26 of Set 49 | barentsburg
# Processing Record 27 of Set 49 | mount isa
# Processing Record 28 of Set 49 | lebu
# Processing Record 29 of Set 49 | castro
# Processing Record 30 of Set 49 | faya
# Processing Record 31 of Set 49 | bambous virieux
# Processing Record 32 of Set 49 | shahr-e kord
# Processing Record 33 of Set 49 | khatanga
# Processing Record 34 of Set 49 | atuona
# Processing Record 35 of Set 49 | sao felix do xingu
# Processing Record 36 of Set 49 | alappuzha
# Processing Record 37 of Set 49 | killam
# Processing Record 38 of Set 49 | bluff
# Processing Record 39 of Set 49 | nanortalik
# Processing Record 40 of Set 49 | sulangan
# Processing Record 41 of Set 49 | mariental
# Processing Record 42 of Set 49 | bolungarvik
# Processing Record 43 of Set 49 | beringovskiy
# Processing Record 44 of Set 49 | tilichiki
# Processing Record 45 of Set 49 | kapaa
# Processing Record 46 of Set 49 | haines junction
# Processing Record 47 of Set 49 | puerto padre
# Processing Record 48 of Set 49 | north vernon
# Processing Record 49 of Set 49 | saldanha
# Processing Record 50 of Set 49 | jamestown
# Processing Record 1 of Set 50 | busselton
# Processing Record 2 of Set 50 | hilo
# Processing Record 3 of Set 50 | korla
# Processing Record 4 of Set 50 | sao jose da coroa grande
# Processing Record 5 of Set 50 | arraial do cabo
# Processing Record 6 of Set 50 | puerto ayora
# Processing Record 7 of Set 50 | namibe
# Processing Record 8 of Set 50 | dolores
# Processing Record 9 of Set 50 | okha
# Processing Record 10 of Set 50 | palabuhanratu
# Processing Record 11 of Set 50 | georgetown
# Processing Record 12 of Set 50 | hithadhoo
# Processing Record 13 of Set 50 | coihaique
# Processing Record 14 of Set 50 | east london
# Processing Record 15 of Set 50 | isangel
# Processing Record 16 of Set 50 | butaritari
# Processing Record 17 of Set 50 | madarounfa
# Processing Record 18 of Set 50 | monkey bay
# Processing Record 19 of Set 50 | bandundu
# Processing Record 20 of Set 50 | sitka
# Processing Record 21 of Set 50 | avarua
# Processing Record 22 of Set 50 | portland
# Processing Record 23 of Set 50 | nikolskoye
# Processing Record 24 of Set 50 | albany
# Processing Record 25 of Set 50 | coquimbo
# Processing Record 26 of Set 50 | grindavik
# Processing Record 27 of Set 50 | bam
# Processing Record 28 of Set 50 | ouargaye
# Processing Record 29 of Set 50 | ferrol
# Processing Record 30 of Set 50 | zolotinka
# Processing Record 31 of Set 50 | den chai
# Processing Record 32 of Set 50 | hami
# Processing Record 33 of Set 50 | aguimes
# Processing Record 34 of Set 50 | sungairaya
# Processing Record 35 of Set 50 | port alfred
# Processing Record 36 of Set 50 | geraldton
# Processing Record 37 of Set 50 | saskylakh
# Processing Record 38 of Set 50 | saint george
# Processing Record 39 of Set 50 | utiroa
# Processing Record 40 of Set 50 | tiksi
# Processing Record 41 of Set 50 | sao joao da barra
# Processing Record 42 of Set 50 | galle
# Processing Record 43 of Set 50 | thompson
# Processing Record 44 of Set 50 | marinette
# Processing Record 45 of Set 50 | quatre cocos
# Processing Record 46 of Set 50 | saint anthony
# Processing Record 47 of Set 50 | erzin
# Processing Record 48 of Set 50 | kazerun
# Processing Record 49 of Set 50 | hobart
# Processing Record 50 of Set 50 | kviteseid
# Processing Record 1 of Set 51 | goundam
# Processing Record 2 of Set 51 | port lincoln
# Processing Record 3 of Set 51 | turukhansk
# Processing Record 4 of Set 51 | bambanglipuro
# Processing Record 5 of Set 51 | opuwo
# Processing Record 6 of Set 51 | timmins
# Processing Record 7 of Set 51 | elko
# Processing Record 8 of Set 51 | hermanus
# Processing Record 9 of Set 51 | yamethin
# Processing Record 10 of Set 51 | provideniya
# Processing Record 11 of Set 51 | batagay-alyta
# Processing Record 12 of Set 51 | deputatskiy
# Processing Record 13 of Set 51 | ketchikan
# Processing Record 14 of Set 51 | ocos
# Processing Record 15 of Set 51 | louis trichardt
# Processing Record 16 of Set 51 | tumannyy
# Processing Record 17 of Set 51 | chapais
# Processing Record 18 of Set 51 | port elizabeth
# Processing Record 19 of Set 51 | barrow
# Processing Record 20 of Set 51 | ilulissat
# Processing Record 21 of Set 51 | ust-kamchatsk
# Processing Record 22 of Set 51 | daphne
# Processing Record 23 of Set 51 | amderma
# Processing Record 24 of Set 51 | dawei
# Processing Record 25 of Set 51 | yerbogachen
# Processing Record 26 of Set 51 | luganville
# Processing Record 27 of Set 51 | dhidhdhoo
# Processing Record 28 of Set 51 | sabha
# Processing Record 29 of Set 51 | port-gentil
# Processing Record 30 of Set 51 | ust-nera
# Processing Record 31 of Set 51 | la ronge
# Processing Record 32 of Set 51 | bolshaya chernigovka
# Processing Record 33 of Set 51 | tocopilla
# Processing Record 34 of Set 51 | zhanjiang
# Processing Record 35 of Set 51 | sentyabrskiy
# Processing Record 36 of Set 51 | leningradskiy
# Processing Record 37 of Set 51 | pingliang
# Processing Record 38 of Set 51 | polczyn-zdroj
# Processing Record 39 of Set 51 | santa maria del oro
# Processing Record 40 of Set 51 | esperance
# Processing Record 41 of Set 51 | cherskiy
# Processing Record 42 of Set 51 | morales
# Processing Record 43 of Set 51 | buala
# Processing Record 44 of Set 51 | tilaran
# Processing Record 45 of Set 51 | saint-philippe
# Processing Record 46 of Set 51 | upernavik
# Processing Record 47 of Set 51 | severo-kurilsk
# Processing Record 48 of Set 51 | fort nelson
# Processing Record 49 of Set 51 | santa lucia
# Processing Record 50 of Set 51 | halalo
# Processing Record 1 of Set 52 | udachnyy
# Processing Record 2 of Set 52 | bredasdorp
# Processing Record 3 of Set 52 | vaitupu
# Processing Record 4 of Set 52 | dingle
# Processing Record 5 of Set 52 | sarangani
# Processing Record 6 of Set 52 | santa isabel do rio negro
# Processing Record 7 of Set 52 | nizhneyansk
# Processing Record 8 of Set 52 | the pas
# Processing Record 9 of Set 52 | verkhnyaya inta
# Processing Record 10 of Set 52 | umzimvubu
# Processing Record 11 of Set 52 | aflu
# Processing Record 12 of Set 52 | hamilton
# Processing Record 13 of Set 52 | guerrero negro
# Processing Record 14 of Set 52 | clyde river
# Processing Record 15 of Set 52 | matara
# Processing Record 16 of Set 52 | lamu
# Processing Record 17 of Set 52 | masumbwe
# Processing Record 18 of Set 52 | rolim de moura
# Processing Record 19 of Set 52 | faanui
# Processing Record 20 of Set 52 | naze
# Processing Record 21 of Set 52 | upata
# Processing Record 22 of Set 52 | chokurdakh
# Processing Record 23 of Set 52 | makasar
# Processing Record 24 of Set 52 | labutta
# Processing Record 25 of Set 52 | rorvik
# Processing Record 26 of Set 52 | mount gambier
# Processing Record 27 of Set 52 | yellowknife
# Processing Record 28 of Set 52 | teneguiban
# Processing Record 29 of Set 52 | gafargaon
# Processing Record 30 of Set 52 | nemuro
# Processing Record 31 of Set 52 | dipkarpaz
# Processing Record 32 of Set 52 | uzhur
# Processing Record 33 of Set 52 | mahebourg
# Processing Record 34 of Set 52 | illoqqortoormiut
# Processing Record 35 of Set 52 | pechenga
# Processing Record 36 of Set 52 | nuevitas
# Processing Record 37 of Set 52 | pevek
# Processing Record 38 of Set 52 | margate
# Processing Record 39 of Set 52 | shetpe
# Processing Record 40 of Set 52 | chuy
# Processing Record 41 of Set 52 | te anau
# Processing Record 42 of Set 52 | mosquera
# Processing Record 43 of Set 52 | peniche
# Processing Record 44 of Set 52 | carmen
# Processing Record 45 of Set 52 | azle
# Processing Record 46 of Set 52 | cabo san lucas
# Processing Record 47 of Set 52 | souillac
# Processing Record 48 of Set 52 | beinamar
# Processing Record 49 of Set 52 | touros
# Processing Record 50 of Set 52 | selfoss
# Processing Record 1 of Set 53 | nizhniy tsasuchey
# Processing Record 2 of Set 53 | canico
# Processing Record 3 of Set 53 | karaul
# Processing Record 4 of Set 53 | inhambane
# Processing Record 5 of Set 53 | constitucion
# Processing Record 6 of Set 53 | tomatlan
# Processing Record 7 of Set 53 | vardo
# Processing Record 8 of Set 53 | saint-joseph
# Processing Record 9 of Set 53 | punta arenas
# Processing Record 10 of Set 53 | teguldet
# Processing Record 11 of Set 53 | maragogi
# Processing Record 12 of Set 53 | camacupa
# Processing Record 13 of Set 53 | linfen
# Processing Record 14 of Set 53 | olongapo
# Processing Record 15 of Set 53 | torbay
# Processing Record 16 of Set 53 | bengkulu
# Processing Record 17 of Set 53 | valparaiso
# Processing Record 18 of Set 53 | mersing
# Processing Record 19 of Set 53 | samusu
# Processing Record 20 of Set 53 | vestmannaeyjar
# Processing Record 21 of Set 53 | kamenskoye
# Processing Record 22 of Set 53 | alofi
# Processing Record 23 of Set 53 | minador do negrao
# Processing Record 24 of Set 53 | ponta do sol
# Processing Record 25 of Set 53 | tiarei
# Processing Record 26 of Set 53 | riyadh
# Processing Record 27 of Set 53 | longyearbyen
# Processing Record 28 of Set 53 | mayo
# Processing Record 29 of Set 53 | gunjur
# Processing Record 30 of Set 53 | melbu
# Processing Record 31 of Set 53 | coxim
# Processing Record 32 of Set 53 | narsaq
# Processing Record 33 of Set 53 | ust-omchug
# Processing Record 34 of Set 53 | mar del plata
# Processing Record 35 of Set 53 | kaitangata
# Processing Record 36 of Set 53 | kavieng
# Processing Record 37 of Set 53 | padang
# Processing Record 38 of Set 53 | victoria
# Processing Record 39 of Set 53 | salalah
# Processing Record 40 of Set 53 | mossendjo
# Processing Record 41 of Set 53 | san cristobal
# Processing Record 42 of Set 53 | koslan
# Processing Record 43 of Set 53 | half moon bay
# Processing Record 44 of Set 53 | bose
# Processing Record 45 of Set 53 | pidhorodne
# Processing Record 46 of Set 53 | boralday
# Processing Record 47 of Set 53 | nikolayevka
# Processing Record 48 of Set 53 | talara
# Processing Record 49 of Set 53 | alice springs
# Processing Record 50 of Set 53 | nova soure
# Processing Record 1 of Set 54 | bilma
# Processing Record 2 of Set 54 | vostok
# Processing Record 3 of Set 54 | caravelas
# Processing Record 4 of Set 54 | sabang
# Processing Record 5 of Set 54 | dikson
# Processing Record 6 of Set 54 | mizdah
# Processing Record 7 of Set 54 | skalistyy
# Processing Record 8 of Set 54 | bima
# Processing Record 9 of Set 54 | coos bay
# Processing Record 10 of Set 54 | cidreira
# Processing Record 11 of Set 54 | lompoc
# Processing Record 12 of Set 54 | glasgow
# Processing Record 13 of Set 54 | xunchang
# Processing Record 14 of Set 54 | harlingen
# Processing Record 15 of Set 54 | okhotsk
# Processing Record 16 of Set 54 | kathmandu
# Processing Record 17 of Set 54 | burnie
# Processing Record 18 of Set 54 | nizhneudinsk
# Processing Record 19 of Set 54 | westport
# Processing Record 20 of Set 54 | tuktoyaktuk
# Processing Record 21 of Set 54 | bethel
# Processing Record 22 of Set 54 | atar
# Processing Record 23 of Set 54 | umba
# Processing Record 24 of Set 54 | carazinho
# Processing Record 25 of Set 54 | baykit
# Processing Record 26 of Set 54 | vila velha
# Processing Record 27 of Set 54 | ribeira grande
# Processing Record 28 of Set 54 | broken hill
# Processing Record 29 of Set 54 | kavali
# Processing Record 30 of Set 54 | nador
# Processing Record 31 of Set 54 | samarai
# Processing Record 32 of Set 54 | laguna
# Processing Record 33 of Set 54 | puerto cabezas
# Processing Record 34 of Set 54 | cacoal
# Processing Record 35 of Set 54 | poum
# Processing Record 36 of Set 54 | sainte-rose
# Processing Record 37 of Set 54 | urdzhar
# Processing Record 38 of Set 54 | omboue
# Processing Record 39 of Set 54 | north myrtle beach
# Processing Record 40 of Set 54 | zomin
# Processing Record 41 of Set 54 | davila
# Processing Record 42 of Set 54 | saint-augustin
# Processing Record 43 of Set 54 | tautira
# Processing Record 44 of Set 54 | karasjok
# Processing Record 45 of Set 54 | akdepe
# Processing Record 46 of Set 54 | barawe
# Processing Record 47 of Set 54 | hualmay
# Processing Record 48 of Set 54 | fairbanks
# Processing Record 49 of Set 54 | coromandel
# Processing Record 50 of Set 54 | port blair
# Processing Record 1 of Set 55 | tuatapere
# Processing Record 2 of Set 55 | lavrentiya
# Processing Record 3 of Set 55 | san patricio
# Processing Record 4 of Set 55 | neusiedl am see
# Processing Record 5 of Set 55 | ruatoria
# Processing Record 6 of Set 55 | srednekolymsk
# Processing Record 7 of Set 55 | saint-pierre
# Processing Record 8 of Set 55 | aklavik
# Processing Record 9 of Set 55 | cordoba
# Processing Record 10 of Set 55 | esil
# Processing Record 11 of Set 55 | requena
# Processing Record 12 of Set 55 | mporokoso
# Processing Record 13 of Set 55 | damietta
# Processing Record 14 of Set 55 | machico
# Processing Record 15 of Set 55 | pundaguitan
# Processing Record 16 of Set 55 | kambove
# Processing Record 17 of Set 55 | erenhot
# Processing Record 18 of Set 55 | indian head
# Processing Record 19 of Set 55 | amurzet
# Processing Record 20 of Set 55 | imbituba
# Processing Record 21 of Set 55 | morristown
# Processing Record 22 of Set 55 | huilong
# Processing Record 23 of Set 55 | sur
# Processing Record 24 of Set 55 | klaksvik
# Processing Record 25 of Set 55 | liancheng
# Processing Record 26 of Set 55 | las guacamayas
# Processing Record 27 of Set 55 | varkaus
# Processing Record 28 of Set 55 | shimoda
# Processing Record 29 of Set 55 | kahului
# Processing Record 30 of Set 55 | pisco
# Processing Record 31 of Set 55 | leshukonskoye
# Processing Record 32 of Set 55 | kismayo
# Processing Record 33 of Set 55 | pandan niog
# Processing Record 34 of Set 55 | mookane
# Processing Record 35 of Set 55 | raga
# Processing Record 36 of Set 55 | ibotirama
# Processing Record 37 of Set 55 | zaria
# Processing Record 38 of Set 55 | ancud
# Processing Record 39 of Set 55 | uvaly
# Processing Record 40 of Set 55 | norman wells
# Processing Record 41 of Set 55 | esik
# Processing Record 42 of Set 55 | nha trang
# Processing Record 43 of Set 55 | husavik
# Processing Record 44 of Set 55 | kozhva
# Processing Record 45 of Set 55 | plettenberg bay
# Processing Record 46 of Set 55 | beidao
# Processing Record 47 of Set 55 | itarema
# Processing Record 48 of Set 55 | merauke
# Processing Record 49 of Set 55 | hambantota
# Processing Record 50 of Set 55 | paamiut
# Processing Record 1 of Set 56 | diapaga
# Processing Record 2 of Set 56 | gryazovets
# Processing Record 3 of Set 56 | meulaboh
# Processing Record 4 of Set 56 | paracuru
# Processing Record 5 of Set 56 | rawannawi
# Processing Record 6 of Set 56 | lagoa
# Processing Record 7 of Set 56 | pecos
# Processing Record 8 of Set 56 | maarianhamina
# Processing Record 9 of Set 56 | zhezkazgan
# Processing Record 10 of Set 56 | la rioja
# Processing Record 11 of Set 56 | benjamin hill
# Processing Record 12 of Set 56 | xai-xai
# Processing Record 13 of Set 56 | vila
# Processing Record 14 of Set 56 | labuhan
# Processing Record 15 of Set 56 | seaford
# Processing Record 16 of Set 56 | manokwari
# Processing Record 17 of Set 56 | bouar
# Processing Record 18 of Set 56 | anito
# Processing Record 19 of Set 56 | cairns
# Processing Record 20 of Set 56 | saleaula
# Processing Record 21 of Set 56 | benghazi
# Processing Record 22 of Set 56 | marana
# Processing Record 23 of Set 56 | ostrovnoy
# Processing Record 24 of Set 56 | roald
# Processing Record 25 of Set 56 | cam ranh
# Processing Record 26 of Set 56 | acajutla
# Processing Record 27 of Set 56 | serenje
# Processing Record 28 of Set 56 | praia da vitoria
# Processing Record 29 of Set 56 | alekseyevsk
# Processing Record 30 of Set 56 | urusha
# Processing Record 31 of Set 56 | hasaki
# Processing Record 32 of Set 56 | jumla
# Processing Record 33 of Set 56 | kisesa
# Processing Record 34 of Set 56 | yarmouth
# Processing Record 35 of Set 56 | moa
# Processing Record 36 of Set 56 | komsomolskiy
# Processing Record 37 of Set 56 | tessalit
# Processing Record 38 of Set 56 | taoudenni
# Processing Record 39 of Set 56 | orvault
# Processing Record 40 of Set 56 | victor harbor
# Processing Record 41 of Set 56 | ribeira brava
# Processing Record 42 of Set 56 | mao
# Processing Record 43 of Set 56 | shubarshi
# Processing Record 44 of Set 56 | attawapiskat
# Processing Record 45 of Set 56 | fergus falls
# Processing Record 46 of Set 56 | aripuana
# Processing Record 47 of Set 56 | sorrento
# Processing Record 48 of Set 56 | honningsvag
# Processing Record 49 of Set 56 | krasnoborsk
# Processing Record 50 of Set 56 | mys shmidta
# Processing Record 1 of Set 57 | sovetskiy
# Processing Record 2 of Set 57 | bay roberts
# Processing Record 3 of Set 57 | meyungs
# Processing Record 4 of Set 57 | madhipura
# Processing Record 5 of Set 57 | abu samrah
# Processing Record 6 of Set 57 | vila franca do campo
# Processing Record 7 of Set 57 | rio das pedras
# Processing Record 8 of Set 57 | neiafu
# Processing Record 9 of Set 57 | sedona
# Processing Record 10 of Set 57 | luderitz
# Processing Record 11 of Set 57 | pangnirtung
# Processing Record 12 of Set 57 | umri
# Processing Record 13 of Set 57 | seymchan
# Processing Record 14 of Set 57 | kedougou
# Processing Record 15 of Set 57 | dubbo
# Processing Record 16 of Set 57 | tasiilaq
# Processing Record 17 of Set 57 | torres vedras
# Processing Record 18 of Set 57 | asau
# Processing Record 19 of Set 57 | richards bay
# Processing Record 20 of Set 57 | launceston
# Processing Record 21 of Set 57 | kaeo
# Processing Record 22 of Set 57 | marystown
# Processing Record 23 of Set 57 | anadyr
# Processing Record 24 of Set 57 | noumea
# Processing Record 25 of Set 57 | waipawa
# Processing Record 26 of Set 57 | katsuura
# Processing Record 27 of Set 57 | charlestown
# Processing Record 28 of Set 57 | olafsvik
# Processing Record 29 of Set 57 | wisconsin rapids
# Processing Record 30 of Set 57 | malwan
# Processing Record 31 of Set 57 | wahran
# Processing Record 32 of Set 57 | cockburn town
# Processing Record 33 of Set 57 | luanda
# Processing Record 34 of Set 57 | ugoofaaru
# Processing Record 35 of Set 57 | vega de alatorre
# Processing Record 36 of Set 57 | nouadhibou
# Processing Record 37 of Set 57 | dubrovka
# Processing Record 38 of Set 57 | dianopolis
# Processing Record 39 of Set 57 | poltavka
# Processing Record 40 of Set 57 | were ilu
# Processing Record 41 of Set 57 | diego de almagro
# Processing Record 42 of Set 57 | tigzirt
# Processing Record 43 of Set 57 | luena
# Processing Record 44 of Set 57 | otane
# Processing Record 45 of Set 57 | acapulco
# Processing Record 46 of Set 57 | pochutla
# Processing Record 47 of Set 57 | pasighat
# Processing Record 48 of Set 57 | pilna
# Processing Record 49 of Set 57 | isla
# Processing Record 50 of Set 57 | ijaki
# Processing Record 1 of Set 58 | wadi
# Processing Record 2 of Set 58 | katangli
# Processing Record 3 of Set 58 | grand river south east
# Processing Record 4 of Set 58 | dunedin
# Processing Record 5 of Set 58 | gashua
# Processing Record 6 of Set 58 | evensk
# Processing Record 7 of Set 58 | oriximina
# Processing Record 8 of Set 58 | lolua
# Processing Record 9 of Set 58 | bauchi
# Processing Record 10 of Set 58 | sangeorgiu-de-padure
# Processing Record 11 of Set 58 | deniliquin
# Processing Record 12 of Set 58 | viedma
# Processing Record 13 of Set 58 | tselinnoye
# Processing Record 14 of Set 58 | sainte-marie
# Processing Record 15 of Set 58 | bayji
# Processing Record 16 of Set 58 | college
# Processing Record 17 of Set 58 | vung tau
# Processing Record 18 of Set 58 | prince rupert
# Processing Record 19 of Set 58 | porto belo
# Processing Record 20 of Set 58 | trapani
# Processing Record 21 of Set 58 | umm lajj
# Processing Record 22 of Set 58 | vieste
# Processing Record 23 of Set 58 | south lake tahoe
# Processing Record 24 of Set 58 | voh
# Processing Record 25 of Set 58 | sao filipe
# Processing Record 26 of Set 58 | rio grande
# Processing Record 27 of Set 58 | progress
# Processing Record 28 of Set 58 | alta floresta
# Processing Record 29 of Set 58 | whitehorse
# Processing Record 30 of Set 58 | calamar
# Processing Record 31 of Set 58 | marawi
# Processing Record 32 of Set 58 | nanakuli
# Processing Record 33 of Set 58 | kholodnyy
# Processing Record 34 of Set 58 | gonzales
# Processing Record 35 of Set 58 | jasper
# Processing Record 36 of Set 58 | vao
# Processing Record 37 of Set 58 | destin
# Processing Record 38 of Set 58 | birin
# Processing Record 39 of Set 58 | atbasar
# Processing Record 40 of Set 58 | entre rios
# Processing Record 41 of Set 58 | vanavara
# Processing Record 42 of Set 58 | tsihombe
# Processing Record 43 of Set 58 | yuanping
# Processing Record 44 of Set 58 | flinders
# Processing Record 45 of Set 58 | manavalakurichi
# Processing Record 46 of Set 58 | iqaluit
# Processing Record 47 of Set 58 | dicamay
# Processing Record 48 of Set 58 | pozo colorado
# Processing Record 49 of Set 58 | constantine
# Processing Record 50 of Set 58 | buraydah
# Processing Record 1 of Set 59 | sioux lookout
# Processing Record 2 of Set 59 | mutoko
# Processing Record 3 of Set 59 | kabinda
# Processing Record 4 of Set 59 | byron bay
# Processing Record 5 of Set 59 | raudeberg
# Processing Record 6 of Set 59 | gasa
# Processing Record 7 of Set 59 | nagorsk
# Processing Record 8 of Set 59 | sobolevo
# Processing Record 9 of Set 59 | oktyabrskiy
# Processing Record 10 of Set 59 | paita
# Processing Record 11 of Set 59 | san jose
# Processing Record 12 of Set 59 | wewak
# Processing Record 13 of Set 59 | tarata
# Processing Record 14 of Set 59 | staroaleyskoye
# Processing Record 15 of Set 59 | turayf
# Processing Record 16 of Set 59 | gat
# Processing Record 17 of Set 59 | mahibadhoo
# Processing Record 18 of Set 59 | port hardy
# Processing Record 19 of Set 59 | omsukchan
# Processing Record 20 of Set 59 | balkanabat
# Processing Record 21 of Set 59 | nisia floresta
# Processing Record 22 of Set 59 | nyurba
# Processing Record 23 of Set 59 | sechura
# Processing Record 24 of Set 59 | dalby
# Processing Record 25 of Set 59 | soyo
# Processing Record 26 of Set 59 | zhanaozen
# Processing Record 27 of Set 59 | takanabe
# Processing Record 28 of Set 59 | dunmanway
# Processing Record 29 of Set 59 | trinidad
# Processing Record 30 of Set 59 | mwene-ditu
# Processing Record 31 of Set 59 | bolshiye kaybitsy
# Processing Record 32 of Set 59 | awjilah
# Processing Record 33 of Set 59 | pacific grove
# Processing Record 34 of Set 59 | tura
# Processing Record 35 of Set 59 | rawah
# Processing Record 36 of Set 59 | olavarria
# Processing Record 37 of Set 59 | serov
# Processing Record 38 of Set 59 | manta
# Processing Record 39 of Set 59 | mayumba
# Processing Record 40 of Set 59 | verkhnevilyuysk
# Processing Record 41 of Set 59 | kurchum
# Processing Record 42 of Set 59 | stornoway
# Processing Record 43 of Set 59 | banda aceh
# Processing Record 44 of Set 59 | kampot
# Processing Record 45 of Set 59 | hastings
# Processing Record 46 of Set 59 | almeirim
# Processing Record 47 of Set 59 | shingu
# Processing Record 48 of Set 59 | lodja
# Processing Record 49 of Set 59 | abu jubayhah
# Processing Record 50 of Set 59 | olga
# Processing Record 1 of Set 60 | garden city
# Processing Record 2 of Set 60 | presidencia roque saenz pena
# Processing Record 3 of Set 60 | alanya
# Processing Record 4 of Set 60 | fort-shevchenko
# Processing Record 5 of Set 60 | broome
# Processing Record 6 of Set 60 | alta gracia
# Processing Record 7 of Set 60 | san carlos de bariloche
# Processing Record 8 of Set 60 | abrau-dyurso
# Processing Record 9 of Set 60 | havre-saint-pierre
# Processing Record 10 of Set 60 | tabou
# Processing Record 11 of Set 60 | sassandra
# Processing Record 12 of Set 60 | karratha
# Processing Record 13 of Set 60 | antofagasta
# Processing Record 14 of Set 60 | issaquah
# Processing Record 15 of Set 60 | sangueya
# Processing Record 16 of Set 60 | mecca
# Processing Record 17 of Set 60 | necochea
# Processing Record 18 of Set 60 | lima
# Processing Record 19 of Set 60 | izvestkovyy
# Processing Record 20 of Set 60 | lynn haven
# Processing Record 21 of Set 60 | nome
# Processing Record 22 of Set 60 | uk
# Processing Record 23 of Set 60 | barcelos
# Processing Record 24 of Set 60 | kingaroy
# Processing Record 25 of Set 60 | bubaque
# Processing Record 26 of Set 60 | digha
# Processing Record 27 of Set 60 | sayyan
# Processing Record 28 of Set 60 | yulara
# Processing Record 29 of Set 60 | rio gallegos
# Processing Record 30 of Set 60 | lake wales
# Processing Record 31 of Set 60 | ramanuj ganj
# Processing Record 32 of Set 60 | belaya gora
# Processing Record 33 of Set 60 | avera
# Processing Record 34 of Set 60 | wick
# Processing Record 35 of Set 60 | charagua
# Processing Record 36 of Set 60 | narrabri
# Processing Record 37 of Set 60 | myaundzha
# Processing Record 38 of Set 60 | muisne
# Processing Record 39 of Set 60 | camacari
# Processing Record 40 of Set 60 | shaoxing
# Processing Record 41 of Set 60 | dobsice
# Processing Record 42 of Set 60 | eureka
# Processing Record 43 of Set 60 | dakoro
# Processing Record 44 of Set 60 | ginir
# Processing Record 45 of Set 60 | gimli
# Processing Record 46 of Set 60 | abdulino
# Processing Record 47 of Set 60 | kununurra
# Processing Record 48 of Set 60 | sorland
# Processing Record 49 of Set 60 | nuuk
# Processing Record 50 of Set 60 | puno
# Processing Record 1 of Set 61 | cururupu
# Processing Record 2 of Set 61 | hobyo
# Processing Record 3 of Set 61 | los llanos de aridane
# Processing Record 4 of Set 61 | oga
# Processing Record 5 of Set 61 | deqing
# Processing Record 6 of Set 61 | kruisfontein

# %%
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8e8c97829fd221b9ed8849cd6e670525&q=kruisfontein'

# %%
import requests as req
from config import weather_api_key

# %%
# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
        print("City not found. Skipping...")


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Volyne  49.17  13.89        45        90          78        1.01
# 1        Volyne  49.17  13.89        45        91          82        1.01
# 2        Volyne  49.17  13.89        45        91          82        1.01
# 3  Kruisfontein -34.00  24.73        64        98         100        5.37
#
#   Country                 Date
# 0      CZ  2020-11-16 23:31:52
# 1      CZ  2020-11-17 04:52:41
# 2      CZ  2020-11-17 04:53:06
# 3      ZA  2020-11-17 04:56:11

# %%
#rearrange the column order
new_column_order = ["City", "Country", "Date", "Lat", "Lng", 
                   "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
#assign new order to data frame City Data
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat    Lng  Max Temp  \
# 0        Volyne      CZ  2020-11-16 23:31:52  49.17  13.89        45
# 1        Volyne      CZ  2020-11-17 04:52:41  49.17  13.89        45
# 2        Volyne      CZ  2020-11-17 04:53:06  49.17  13.89        45
# 3  Kruisfontein      ZA  2020-11-17 04:56:11 -34.00  24.73        64
#
#    Humidity  Cloudiness  Wind Speed
# 0        90          78        1.01
# 1        91          82        1.01
# 2        91          82        1.01
# 3        98         100        5.37

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
